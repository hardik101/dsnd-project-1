# %% [markdown]
# In this notebook, we will have a quick look at our datasets.
# We will be using airbnb datasets for boston and seattle cities.
#
# We would like to answer the follwing business questions:
#
# 1. Which are influencing factors for 'listing price' in each city?
# 2. Identifying the busiest time of the year to visit each city?
# 3. Free Text (Review) analysis and how it correlates with average review?

# %%
#Import necessary dependencies
import pandas as pd

# %%
#Let's load the listings file for boston dataset in df_listing dataframe

boston_df_listings = pd.read_csv('../data/boston/listings.csv')
boston_df_listings.head(5)

# %%
#Let's load the reviews file for boston dataset in df_listing dataframe

boston_df_reviews = pd.read_csv('../data/boston/reviews.csv')
boston_df_reviews.head(5)

# %%
boston_df_calendar = pd.read_csv('../data/boston/calendar.csv')
boston_df_calendar.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
#Let's load the listings file for boston dataset in df_listing dataframe

seattle_df_listings = pd.read_csv('../data/seattle/listings.csv')

print(seattle_df_listings.columns) #lists all the colums to have quick look

seattle_df_listings.head(5)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
#Let's load the reviews file for boston dataset in df_listing dataframe

seattle_df_reviews = pd.read_csv('../data/seattle/reviews.csv')

seattle_df_reviews.head(5)
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
seattle_df_calendar = pd.read_csv('../data/seattle/calendar.csv')

seattle_df_calendar.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
import pandas as pd

#Import visualization packages

import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#find out number of unique hosts and number of unique listings in Seattle Area

seattle_listings_count = seattle_df_listings['id'].count()
seattle_hosts_count = len(seattle_df_listings['host_id'].unique())

print('Listing count: %d , Hosts count: %d' %(seattle_listings_count,seattle_hosts_count))
# Out:
# Listing count: 3818 , Hosts count: 2751

# %%
#Let's have a look at missing values in each columns

seattle_listings_missing_df = seattle_df_listings.isnull().mean()*100

seattle_listings_missing_df

#All the columns with some missing values
seattle_listings_columns_missing_with_nan = seattle_df_listings.loc[:,seattle_listings_missing_df > 0]

#All the columns with no missing values
#seattle_df_listings.loc[:,seattle_listings_missing_df == 0]

#All the columns with more then 10% missing values 
#seattle_df_listings.loc[:,seattle_listings_missing_df > 10]


seattle_listings_columns_missing_with_nan.plot.bar(title = "Missing values in % per column in Seattle")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-c9e27f36035e> in <module>
#      15
#      16
# ---> 17 seattle_listings_columns_missing_with_nan.plot.bar(title = "Missing values in % per column in Seattle")
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1001             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    1002         """
# -> 1003         return self(kind="bar", x=x, y=y, **kwargs)
#    1004
#    1005     def barh(self, x=None, y=None, **kwargs):
#
# /usr/local/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...
